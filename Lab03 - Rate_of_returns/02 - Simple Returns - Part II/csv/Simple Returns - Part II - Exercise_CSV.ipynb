# %% [markdown]
# ## Simple Returns - Part II

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
MSFT = pd.read_csv('MSFT_2000_2017.csv', index_col = 'Date')
MSFT['simple_return'] = (MSFT['Adj Close'] / MSFT['Adj Close'].shift(1)) - 1
print(MSFT['simple_return'])
# Out:
# Date
# 1999-12-31         NaN
# 2000-01-03   -0.001606
# 2000-01-04   -0.033780
# 2000-01-05    0.010544
# 2000-01-06   -0.033498
#                 ...
# 2017-12-06    0.014585
# 2017-12-07   -0.003503
# 2017-12-08    0.020245
# 2017-12-11    0.012714
# 2017-12-12    0.003520
# Name: simple_return, Length: 4517, dtype: float64

# %% [markdown]
# Plot the simple returns on a graph.

# %%
MSFT['simple_return'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Calculate the average daily return.

# %%
avg_d = MSFT['simple_return'].mean()
avg_d
# Out:
# 0.00036250887702754563

# %% [markdown]
# Estimate the average annual return.

# %%
avg_a = MSFT['simple_return'].mean() * 250
avg_a
# Out:
# 0.09062721925688641

# %% [markdown]
# Print the percentage version of the result as a float with 2 digits after the decimal point.

# %%
print(str(round(avg_a, 4) * 100) + " %")
# Out:
# 9.06 %
