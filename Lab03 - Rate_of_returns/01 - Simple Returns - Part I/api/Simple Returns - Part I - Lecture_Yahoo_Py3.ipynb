# %%
# !pip install yfinance
# !pip install pandas_datareader

# %%
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

import yfinance as yf
yf.pdr_override()

# %%
PG = wb.DataReader('PG', start='1995-1-1')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
PG.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 1995-01-03  15.46875  15.62500  15.43750  15.59375   7.529935  3318400
# 1995-01-04  15.53125  15.65625  15.31250  15.46875   7.469574  2218800
# 1995-01-05  15.37500  15.43750  15.21875  15.25000   7.363945  2319600
# 1995-01-06  15.15625  15.40625  15.15625  15.28125   7.379035  3438000
# 1995-01-09  15.34375  15.40625  15.18750  15.21875   7.348854  1795200

# %%
PG.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-04-18  156.339996  157.630005  155.960007  157.289993  157.289993
# 2024-04-19  154.979996  158.179993  153.520004  158.139999  158.139999
# 2024-04-22  158.429993  161.289993  157.250000  160.539993  160.539993
# 2024-04-23  161.679993  162.100006  160.419998  161.500000  161.500000
# 2024-04-24  161.199997  162.860001  159.419998  162.600006  162.600006
#
#               Volume
# Date
# 2024-04-18   7819300
# 2024-04-19  12028400
# 2024-04-22   8926300
# 2024-04-23   7707300
# 2024-04-24   7216600

# %% [markdown]
# ## Simple Rate of Return

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
PG['simple_return'] = (PG['Adj Close'] / PG['Adj Close'].shift(1)) - 1
print (PG['simple_return'])
# Out:
# Date
# 1995-01-03         NaN
# 1995-01-04   -0.008016
# 1995-01-05   -0.014141
# 1995-01-06    0.002049
# 1995-01-09   -0.004090
#                 ...
# 2024-04-18    0.008573
# 2024-04-19    0.005404
# 2024-04-22    0.015176
# 2024-04-23    0.005980
# 2024-04-24    0.006811
# Name: simple_return, Length: 7379, dtype: float64
