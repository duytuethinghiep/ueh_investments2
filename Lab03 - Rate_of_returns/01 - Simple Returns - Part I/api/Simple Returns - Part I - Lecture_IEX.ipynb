# %%
# !pip install pyEX
# !pip install iexfinance

# %%
# !pip install quandl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
import quandl
quandl.ApiConfig.api_key = 'Wi5xJFnD9bwKLwazVpvm'
quandl.ApiConfig.verify_ssl = False

# %%
import quandl
data = quandl.get('NSE/OIL')
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.nasdaq.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
data
# Out:
#                Open     High      Low     Last    Close  Total Trade Quantity  \
# Date
# 2009-09-30  1096.00  1156.70  1090.00  1135.00  1141.20            19748012.0
# 2009-10-01  1102.00  1173.70  1102.00  1167.00  1166.35             3074254.0
# 2009-10-05  1152.00  1165.90  1136.60  1143.00  1140.55              919832.0
# 2009-10-06  1149.80  1157.20  1132.10  1143.30  1144.90              627957.0
# 2009-10-07  1153.80  1160.70  1140.00  1141.45  1141.60              698216.0
# ...             ...      ...      ...      ...      ...                   ...
# 2018-12-31   178.10   179.00   174.35   175.00   174.80              761462.0
# 2019-01-01   175.00   176.40   174.15   175.15   175.75              381570.0
# 2019-01-02   175.80   176.20   171.00   172.35   172.40              722532.0
# 2019-01-03   172.80   175.70   171.50   172.00   172.00              698190.0
# 2019-01-04   172.05   174.95   172.05   174.55   174.55              431122.0
#
# ...

# %%
from iexfinance.refdata import get_symbols
from iexfinance.stocks import Stock

token_api = "sk_aa0a04e24b874ad8bbdb7132fba261db"
token_api = "pk_00d4e5f9cbdd44e78cfb6f504be796d0"
a = Stock("PG", token=token_api)
a.get_quote()
# Out:
# ---------------------------------------------------------------------------
# IEXQueryError                             Traceback (most recent call last)
# Cell In[7], line 7
#       5 token_api = "pk_00d4e5f9cbdd44e78cfb6f504be796d0"
#       6 a = Stock("PG", token=token_api)
# ----> 7 a.get_quote()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\iexfinance\stocks\base.py:337, in Stock.get_quote(self, **kwargs)
#     324 def get_quote(self, **kwargs):
#     325     """Quote
#     326
#     327     Reference: https://iexcloud.io/docs/api/#quote
#    (...)
#     335         multiplied by a factor of 100.
#     336     """
# --> 337     return self._get_endpoint("quote", params=kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\iexfinance\stocks\base.py:73, in Stock._get_endpoint(self, endpoint, params, format, filter_)
#      70 self.optional_params = params
#      71 self.endpoints = [endpoint]
# ---> 73 data = self.fetch(format=no_pandas)
# ...

# %%
import os
import pyEX as p

os.environ["IEX_TOKEN"] = "sk_aa0a04e24b874ad8bbdb7132fba261db"
os.environ["IEX_API_KEY"] = "sk_aa0a04e24b874ad8bbdb7132fba261db"
c = p.Client()

# %%
# c.chartDF('AAPL').head()

# %%
import os
os.environ["QUANDL_API_KEY"] = "Wi5xJFnD9bwKLwazVpvm"
PG = wb.DataReader('PG', 'quandl', start='2015-1-1')

# %%
PG[["Open", "High", "Low", "Close", "AdjClose"]]
# Out:
#              Open    High      Low  Close   AdjClose
# Date
# 2018-03-27  76.53  78.440  76.3000  77.79  77.790000
